# %%
import os,sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set()
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("E-com_Data.csv")
df.head()
# Out:
#    CustomerID Item Code  InvoieNo Date of purchase  Quantity        Time  \
# 0      4355.0     15734  398177.0       29-10-2017       6.0  3:36:00 PM
# 1      4352.0     14616  394422.0       05-10-2017       2.0  2:53:00 PM
# 2      4352.0     14614  394422.0       12-10-2017       2.0  2:53:00 PM
# 3      4352.0    85014B  388633.0       22-08-2017       3.0  2:47:00 PM
# 4      4352.0     15364  394422.0       10-10-2017       2.0  2:53:00 PM
#
#    price per Unit   Price Shipping Location Cancelled_status Reason of return  \
# 0           321.0  1926.0        Location 1              NaN              NaN
# 1           870.0  1740.0        Location 1              NaN              NaN
# 2           933.0  1866.0        Location 1              NaN              NaN
# 3           623.0  1869.0        Location 1              NaN              NaN
# 4           944.0  1888.0        Location 1              NaN              NaN
#
#    Sold as set
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
df.shape
# Out:
# (541116, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541116 entries, 0 to 541115
# Data columns (total 12 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   CustomerID         404189 non-null  float64
#  1   Item Code          537979 non-null  object
#  2   InvoieNo           537979 non-null  float64
#  3   Date of purchase   537979 non-null  object
#  4   Quantity           537979 non-null  float64
#  5   Time               537979 non-null  object
#  6   price per Unit     537979 non-null  float64
#  7   Price              537979 non-null  float64
#  8   Shipping Location  537979 non-null  object
#  9   Cancelled_status   8345 non-null    object
#  10  Reason of return   3 non-null       object
#  11  Sold as set        0 non-null       float64
# dtypes: float64(6), object(6)
# memory usage: 49.5+ MB

# %%
# Unique values
df.nunique()
# Out:
# CustomerID            4349
# Item Code             4009
# InvoieNo             24928
# Date of purchase       381
# Quantity               462
# Time                   770
# price per Unit        2900
# Price                13529
# Shipping Location       20
# Cancelled_status         1
# Reason of return         2
# Sold as set              0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# CustomerID           136927
# Item Code              3137
# InvoieNo               3137
# Date of purchase       3137
# Quantity               3137
# Time                   3137
# price per Unit         3137
# Price                  3137
# Shipping Location      3137
# Cancelled_status     532771
# Reason of return     541113
# Sold as set          541116
# dtype: int64

# %%
df.isnull().sum()/len(df)*100
# Out:
# CustomerID            25.304556
# Item Code              0.579728
# InvoieNo               0.579728
# Date of purchase       0.579728
# Quantity               0.579728
# Time                   0.579728
# price per Unit         0.579728
# Price                  0.579728
# Shipping Location      0.579728
# Cancelled_status      98.457817
# Reason of return      99.999446
# Sold as set          100.000000
# dtype: float64

# %%
# Data Cleaning

df.loc[df.duplicated(),:]
# Out:
#         CustomerID Item Code  InvoieNo Date of purchase  Quantity  \
# 61202       4043.0     15819  403353.0       02-12-2017       1.0
# 70587       3984.0     15422  405579.0       09-12-2017      24.0
# 84823       3828.0     14519  398139.0       31-10-2017       1.0
# 120521      3384.0     15121  380588.0       11-06-2017       1.0
# 182786      2607.0     15660  393225.0       30-09-2017       1.0
# ...            ...       ...       ...              ...       ...
# 541111         NaN       NaN       NaN              NaN       NaN
# 541112         NaN       NaN       NaN              NaN       NaN
# 541113         NaN       NaN       NaN              NaN       NaN
# 541114         NaN       NaN       NaN              NaN       NaN
# 541115         NaN       NaN       NaN              NaN       NaN
#
#                Time  price per Unit   Price Shipping Location  \
# 61202    2:07:00 PM           447.0   447.0       Location 36
# 70587    2:09:00 PM            77.0  1848.0       Location 36
# 84823    2:04:00 PM            85.0    85.0       Location 36
# 120521  11:37:00 AM           298.0   298.0       Location 36
# 182786  12:31:00 PM           484.0   484.0       Location 36
# ...             ...             ...     ...               ...
# 541111          NaN             NaN     NaN               NaN
# 541112          NaN             NaN     NaN               NaN
# 541113          NaN             NaN     NaN               NaN
# 541114          NaN             NaN     NaN               NaN
# 541115          NaN             NaN     NaN               NaN
#
#        Cancelled_status Reason of return  Sold as set
# 61202               NaN              NaN          NaN
# 70587               NaN              NaN          NaN
# 84823               NaN              NaN          NaN
# 120521              NaN              NaN          NaN
# 182786              NaN              NaN          NaN
# ...                 ...              ...          ...
# 541111              NaN              NaN          NaN
# 541112              NaN              NaN          NaN
# 541113              NaN              NaN          NaN
# 541114              NaN              NaN          NaN
# 541115              NaN              NaN          NaN
#
# [3145 rows x 12 columns]

# %%
# Drop the duplicate values
df = df.drop_duplicates(ignore_index = True)
df.loc[df.duplicated(),:]
# Out:
# Empty DataFrame
# Columns: [CustomerID, Item Code, InvoieNo, Date of purchase, Quantity, Time, price per Unit, Price, Shipping Location, Cancelled_status, Reason of return, Sold as set]
# Index: []

# %%
df.shape
# Out:
# (537971, 12)

# %%
# We will drop the missing data for CustomerID "Row wise"

# %%
df.isnull().sum()
# Out:
# CustomerID           133790
# Item Code                 1
# InvoieNo                  1
# Date of purchase          1
# Quantity                  1
# Time                      1
# price per Unit            1
# Price                     1
# Shipping Location         1
# Cancelled_status     529626
# Reason of return     537968
# Sold as set          537971
# dtype: int64

# %%
df = df.dropna(subset= ['CustomerID'])

# %%
df.isnull().sum()
# Out:
# CustomerID                0
# Item Code                 0
# InvoieNo                  0
# Date of purchase          0
# Quantity                  0
# Time                      0
# price per Unit            0
# Price                     0
# Shipping Location         0
# Cancelled_status     395998
# Reason of return     404181
# Sold as set          404181
# dtype: int64

# %%
df['date'] = pd.to_datetime(df['Date of purchase'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 404181 entries, 0 to 537940
# Data columns (total 13 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   CustomerID         404181 non-null  float64
#  1   Item Code          404181 non-null  object
#  2   InvoieNo           404181 non-null  float64
#  3   Date of purchase   404181 non-null  object
#  4   Quantity           404181 non-null  float64
#  5   Time               404181 non-null  object
#  6   price per Unit     404181 non-null  float64
#  7   Price              404181 non-null  float64
#  8   Shipping Location  404181 non-null  object
#  9   Cancelled_status   8183 non-null    object
#  10  Reason of return   0 non-null       object
#  11  Sold as set        0 non-null       float64
#  12  date               404181 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(6), object(6)
# memory usage: 43.2+ MB

# %%
df = df.drop(['Sold as set','Reason of return','Cancelled_status', 'Date of purchase'], axis=1)
df.shape
# Out:
# (404181, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 404181 entries, 0 to 537940
# Data columns (total 9 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   CustomerID         404181 non-null  float64
#  1   Item Code          404181 non-null  object
#  2   InvoieNo           404181 non-null  float64
#  3   Quantity           404181 non-null  float64
#  4   Time               404181 non-null  object
#  5   price per Unit     404181 non-null  float64
#  6   Price              404181 non-null  float64
#  7   Shipping Location  404181 non-null  object
#  8   date               404181 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(5), object(3)
# memory usage: 30.8+ MB

# %%
# Objective: Build an unsupervised learning model which can enable your company to analyze their customers.. 
#..via RFM (Recency, Frequency and Monetary value) approach.

## Recency = Latest Date - last invoice date
# Latest Date = Today's date or 

## Frequency = No. of Invoices of the tranction by CustomerID

## Monetary = Sum of total amount purchased by CustomerID

# %%
max(df["date"])
# Out:
# Timestamp('2017-12-19 00:00:00')

# %%
# Last Date- 2017-12-19
# Latest Date - 2017-12-20

import datetime as dt
latest_date = dt.datetime(2017,12,20)
latest_date
# Out:
# datetime.datetime(2017, 12, 20, 0, 0)

# %%
df['Recency'] = df['date']
df['Frequency'] = df['date']
df['Monetary'] = df['Price']

# %%
# Create RFM model by each customer

RMF_score = df.groupby('CustomerID').agg({'Recency': lambda x: (latest_date-x.max()).days,
                                          'Frequency': lambda x : x.count(),
                                          'Monetary': lambda x : x.sum()})

# %%
RMF_score.reset_index().head()
# Out:
#    CustomerID  Recency  Frequency  Monetary
# 0         2.0        4        182  553704.0
# 1         3.0       77         27  257404.0
# 2         4.0       20         72  176613.0
# 3         5.0       18         16   41976.0
# 4         6.0        9         84  151822.0

# %%
## EDA ##`

# %%
RMF_score.Recency.describe()
# Out:
# count    4349.000000
# mean       61.445160
# std        89.656941
# min         1.000000
# 25%        10.000000
# 50%        19.000000
# 75%        73.000000
# max       617.000000
# Name: Recency, dtype: float64

# %%
# Split the data into four segments using quantile method
quantiles = RMF_score.quantile(q = [0.25, 0.50, 0.75])
quantiles = quantiles.to_dict()
quantiles
# Out:
# {'Recency': {0.25: 10.0, 0.5: 19.0, 0.75: 73.0},
#  'Frequency': {0.25: 17.0, 0.5: 42.0, 0.75: 101.0},
#  'Monetary': {0.25: 38148.0, 0.5: 83655.0, 0.75: 205612.0}}

# %%
# Recency- Lesser the better
# Frequency - Higher the better
# Monetary - Higher the better

# %%
# Creating a funtion to define R,F & M segment

def Rscoring(x,p,d):
    if x <= d[p][0.25]:
        return 1
    elif x <= d[p][0.5]:
        return 2
    elif x <= d[p][0.75]:
        return 3
    else:
        return 4
    
def FnMscoring(x,p,d):
    if x <= d[p][0.25]:
        return 4
    elif x<= d[p][0.5]:
        return 3
    elif x<= d[p][0.75]:
        return 2
    else:
        return 1

# %%
RMF_score['R'] = RMF_score['Recency'].apply(Rscoring, args= ('Recency', quantiles,))
RMF_score['F'] = RMF_score['Frequency'].apply(FnMscoring, args= ('Frequency', quantiles,))
RMF_score['M'] = RMF_score['Monetary'].apply(FnMscoring, args= ('Monetary', quantiles,))

# %%
RMF_score.head(20)
# Out:
#             Recency  Frequency  Monetary  R  F  M
# CustomerID
# 2.0               4        182  553704.0  1  1  1
# 3.0              77         27  257404.0  4  3  1
# 4.0              20         72  176613.0  3  2  2
# 5.0              18         16   41976.0  2  4  3
# 6.0               9         84  151822.0  1  2  2
# 7.0             208          4    9410.0  4  4  4
# 8.0             234         58  135550.0  4  2  2
# 9.0              15         13   65832.0  2  4  3
# 10.0             16         58  331601.0  2  2  1
# 11.0              9        131  771439.0  1  1  1
# 12.0              2         17  105674.0  1  4  2
# 13.0             14        254  705406.0  2  1  1
# 14.0             53        126  281630.0  3  1  1
# 15.0            170          9   21630.0  4  4  4
# 16.0              4        264  578591.0  1  1  1
# 17.0             16         23   78378.0  2  3  3
# 18.0              8         81  205212.0  1  2  2
# 19.0            292         21   41055.0  4  3  3
# 20.0              6         10   23537.0  1  4  4
# 21.0             17        166  469518.0  2  1  1

# %%
# RMF_score['Group'] = RMF_score['R']+ RMF_score['F'] + RMF_score['M']
# RMF_score.head()

# %%
# RMF_score['Group'].unique()

# %%
# RMF_score.info()

# %%
# RMF_score['R'] = RMF_score['R'].astype('str')
# RMF_score['F'] = RMF_score['F'].astype('str')
# RMF_score['M'] = RMF_score['M'].astype('str')

# %%
# RMF_score['Cluster'] = RMF_score['R'] + RMF_score['F'] + RMF_score['M']
# RMF_score.head()

# %%
# RMF_score['Cluster'].unique()

# %%
# Best Recency = 1
# Best Frequency = 1
# Best Monetary = 1

# %%
RMF_score['RFM_group'] = RMF_score.R.map(str) + RMF_score.F.map(str) + RMF_score.M.map(str)
RMF_score.head(5)
# Out:
#             Recency  Frequency  Monetary  R  F  M RFM_group
# CustomerID
# 2.0               4        182  553704.0  1  1  1       111
# 3.0              77         27  257404.0  4  3  1       431
# 4.0              20         72  176613.0  3  2  2       322
# 5.0              18         16   41976.0  2  4  3       243
# 6.0               9         84  151822.0  1  2  2       122

# %%
RMF_score['RFM_score'] = RMF_score[['R','F','M']].sum(axis=1)
RMF_score.head(5)
# Out:
#             Recency  Frequency  Monetary  R  F  M RFM_group  RFM_score
# CustomerID
# 2.0               4        182  553704.0  1  1  1       111          3
# 3.0              77         27  257404.0  4  3  1       431          8
# 4.0              20         72  176613.0  3  2  2       322          7
# 5.0              18         16   41976.0  2  4  3       243          9
# 6.0               9         84  151822.0  1  2  2       122          5

# %%
# Assign loyality label to each customer

loyality_level = ['Diamond', 'Platinum', 'Gold', 'Silver']

score_cuts = pd.qcut(RMF_score.RFM_score, q = 4, labels = loyality_level)
RMF_score['Loyality_level'] = score_cuts.values
RMF_score.reset_index().head(10)
# Out:
#    CustomerID  Recency  Frequency  Monetary  R  F  M RFM_group  RFM_score  \
# 0         2.0        4        182  553704.0  1  1  1       111          3
# 1         3.0       77         27  257404.0  4  3  1       431          8
# 2         4.0       20         72  176613.0  3  2  2       322          7
# 3         5.0       18         16   41976.0  2  4  3       243          9
# 4         6.0        9         84  151822.0  1  2  2       122          5
# 5         7.0      208          4    9410.0  4  4  4       444         12
# 6         8.0      234         58  135550.0  4  2  2       422          8
# 7         9.0       15         13   65832.0  2  4  3       243          9
# 8        10.0       16         58  331601.0  2  2  1       221          5
# 9        11.0        9        131  771439.0  1  1  1       111          3
#
#   Loyality_level
# 0        Diamond
# 1       Platinum
# 2       Platinum
# 3           Gold
# 4        Diamond
# 5         Silver
# 6       Platinum
# 7           Gold
# 8        Diamond
# 9        Diamond

# %%
# Validate the data for RFM_hroup = 111

RMF_score[RMF_score['RFM_group'] == '111'].sort_values('Monetary', ascending = False).head(30)
# Out:
#             Recency  Frequency    Monetary  R  F  M RFM_group  RFM_score  \
# CustomerID
# 1704.0            3       2053  35536194.0  1  1  1       111          3
# 1896.0            2       5874  17743855.0  1  1  1       111          3
# 56.0             10        757  14357682.0  1  1  1       111          3
# 1346.0            9       1395  12647317.0  1  1  1       111          3
# 3802.0            3       1060  12319439.0  1  1  1       111          3
# 4234.0            3        322  10654918.0  1  1  1       111          3
# 1006.0            5        571   9351019.0  1  1  1       111          3
# 3203.0            5        269   8102167.0  1  1  1       111          3
# 2193.0            1       2489   7966054.0  1  1  1       111          3
# 1448.0            5       1638   7892625.0  1  1  1       111          3
# 3759.0            9        263   7545149.0  1  1  1       111          3
# 569.0             5       1853   7408035.0  1  1  1       111          3
# 1301.0            5       5099   6146204.0  1  1  1       111          3
# 2000.0            5        402   5920539.0  1  1  1       111          3
# 2723.0           10        226   5754682.0  1  1  1       111          3
# 1296.0            9        589   5678995.0  1  1  1       111          3
# 4043.0            2       7970   5152099.0  1  1  1       111          3
# 3015.0            9        380   5094946.0  1  1  1       111          3
# 2538.0           10        117   5044512.0  1  1  1       111          3
# 1079.0            4        438   4832240.0  1  1  1       111          3
# 3723.0            7        191   4443946.0  1  1  1       111          3
# 331.0             1       4615   4410721.0  1  1  1       111          3
# 565.0             2       1059   3798089.0  1  1  1       111          3
# 577.0             2        605   3654272.0  1  1  1       111          3
# 804.0             3        498   3594149.0  1  1  1       111          3
# 3713.0            3        220   3332232.0  1  1  1       111          3
# 2591.0           10        161   3243332.0  1  1  1       111          3
# 2709.0            5        136   3035863.0  1  1  1       111          3
# 3705.0           10        105   2807583.0  1  1  1       111          3
# 335.0             6        229   2670808.0  1  1  1       111          3
#
#            Loyality_level
# CustomerID
# 1704.0            Diamond
# 1896.0            Diamond
# 56.0              Diamond
# 1346.0            Diamond
# 3802.0            Diamond
# 4234.0            Diamond
# 1006.0            Diamond
# 3203.0            Diamond
# 2193.0            Diamond
# 1448.0            Diamond
# 3759.0            Diamond
# 569.0             Diamond
# 1301.0            Diamond
# 2000.0            Diamond
# 2723.0            Diamond
# 1296.0            Diamond
# 4043.0            Diamond
# 3015.0            Diamond
# 2538.0            Diamond
# 1079.0            Diamond
# 3723.0            Diamond
# 331.0             Diamond
# 565.0             Diamond
# 577.0             Diamond
# 804.0             Diamond
# 3713.0            Diamond
# 2591.0            Diamond
# 2709.0            Diamond
# 3705.0            Diamond
# 335.0             Diamond

# %%
def handle_neg_n_zero(num):
    if num <= 0:
        return 1
    else:
        return num

# %%
# Recency and Frequency don't have any negetive value

RMF_score['Monetary'] = [handle_neg_n_zero(x) for x in RMF_score['Monetary']]

# %%
new_data = RMF_score[['Recency','Frequency','Monetary']]
new_data.head(5)
# Out:
#             Recency  Frequency  Monetary
# CustomerID
# 2.0               4        182  553704.0
# 3.0              77         27  257404.0
# 4.0              20         72  176613.0
# 5.0              18         16   41976.0
# 6.0               9         84  151822.0

# %% [markdown]
# # Feature Scaling

# %%
sns.boxplot(y='Monetary', data= new_data)
# Out:
# <Axes: ylabel='Monetary'>

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaled_data = scaler.fit_transform(new_data)
scaled_data
# Out:
# array([[-0.64079551,  0.38379456,  0.37766904],
#        [ 0.17351282, -0.28413542,  0.03198725],
#        [-0.46231697, -0.09022026, -0.0622685 ],
#        ...,
#        [-0.55155624, -0.34446458, -0.23919388],
#        [-0.64079551,  2.84867167,  0.05905846],
#        [-0.1165148 , -0.09883872,  0.03830589]])

# %%
scaled_data = pd.DataFrame(scaled_data, index=RMF_score.index, columns= new_data.columns)
scaled_data.head()
# Out:
#              Recency  Frequency  Monetary
# CustomerID
# 2.0        -0.640796   0.383795  0.377669
# 3.0         0.173513  -0.284135  0.031987
# 4.0        -0.462317  -0.090220 -0.062268
# 5.0        -0.484627  -0.331537 -0.219344
# 6.0        -0.585021  -0.038510 -0.091191

# %% [markdown]
# # Building Clustering Models

# %%
from sklearn.cluster import KMeans

sum_sq_dist = {}
for i in range(1,20):
    kmeans = KMeans(n_clusters=i, init= 'k-means++', max_iter=1000, random_state=1)
    km = kmeans.fit(scaled_data)
    sum_sq_dist[i] = km.inertia_
    

# Vizualization for Elbow method (to find actual k value)

sns.pointplot(x=list(sum_sq_dist.keys()),
             y = list(sum_sq_dist.values()))
plt.xlabel("Number of clusters(K)")
plt.ylabel("Sum of Square Distance(Euclidean Distance)")
plt.title("Elbow method for finding Optimal K value")
plt.show()

# %%
km = KMeans(n_clusters= 4, init ='k-means++', max_iter=1000)
y_kmeans = km.fit_predict(scaled_data)
y_kmeans
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
RMF_score['Cluster'] = km.labels_
RMF_score.head()
# Out:
#             Recency  Frequency  Monetary  R  F  M RFM_group  RFM_score  \
# CustomerID
# 2.0               4        182  553704.0  1  1  1       111          3
# 3.0              77         27  257404.0  4  3  1       431          8
# 4.0              20         72  176613.0  3  2  2       322          7
# 5.0              18         16   41976.0  2  4  3       243          9
# 6.0               9         84  151822.0  1  2  2       122          5
#
#            Loyality_level  Cluster
# CustomerID
# 2.0               Diamond        0
# 3.0              Platinum        0
# 4.0              Platinum        0
# 5.0                  Gold        0
# 6.0               Diamond        0

# %%
RMF_score.to_excel('Customer_Segmentation_Clusters.xlsx')

# %%
RMF_score['Cluster'].value_counts()
# Out:
# 1    2917
# 0     728
# 5     362
# 6     324
# 4      13
# 3       4
# 2       1
# Name: Cluster, dtype: int64

# %%
RMF_score['Loyality_level'].value_counts()
# Out:
# Diamond     1310
# Platinum    1287
# Gold         939
# Silver       813
# Name: Loyality_level, dtype: int64

# %%
RMF_score.head(5)
# Out:
#             Recency  Frequency  Monetary  R  F  M RFM_group  RFM_score  \
# CustomerID
# 2.0               4        182  553704.0  1  1  1       111          3
# 3.0              77         27  257404.0  4  3  1       431          8
# 4.0              20         72  176613.0  3  2  2       322          7
# 5.0              18         16   41976.0  2  4  3       243          9
# 6.0               9         84  151822.0  1  2  2       122          5
#
#            Loyality_level  Cluster
# CustomerID
# 2.0               Diamond        3
# 3.0              Platinum        3
# 4.0              Platinum        3
# 5.0                  Gold        3
# 6.0               Diamond        3

# %%
# Checking centroids per cluster

centroid_df = RFMScore1.groupby('Cluster')[['Recency', 'Frequency','Monetary','CustomerID']].agg({'Recency':'mean',
                                                                                                 'Frequency': 'mean',
                                                                                                 'Monetary': 'mean',
                                                                                                 'CustomerID':'nunique'}).reset_index()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[79], line 3
#       1 # Checking centroids per cluster
# ----> 3 centroid_df = RFMScore1.groupby('Cluster')[['Recency', 'Frequency','Monetary','CustomerID']].agg({'Recency':'mean',
#       4                                                                                                  'Frequency': 'mean',
#       5                                                                                                  'Monetary': 'mean',
#       6                                                                                                  'CustomerID':'nunique'}).reset_index()
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:8402, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    8399     raise TypeError("You have to supply one of 'by' and 'level'")
#    8400 axis = self._get_axis_number(axis)
# -> 8402 return DataFrameGroupBy(
#    8403     obj=self,
#    8404     keys=by,
#    8405     axis=axis,
#    8406     level=level,
#    8407     as_index=as_index,
#    8408     sort=sort,
#    8409     group_keys=group_keys,
#    8410     squeeze=squeeze,
#    8411     observed=observed,
#    8412     dropna=dropna,
#    8413 )
#
# File ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py:965, in GroupBy.__init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     962 if grouper is None:
#     963     from pandas.core.groupby.grouper import get_grouper
# --> 965     grouper, exclusions, obj = get_grouper(
#     966         obj,
#     967         keys,
#     968         axis=axis,
#     969         level=level,
#     970         sort=sort,
#     971         observed=observed,
#     972         mutated=self.mutated,
#     973         dropna=self.dropna,
#     974     )
#     976 self.obj = obj
#     977 self.axis = obj._get_axis_number(axis)
#
# File ~\anaconda3\lib\site-packages\pandas\core\groupby\grouper.py:888, in get_grouper(obj, key, axis, level, sort, observed, mutated, validate, dropna)
#     886         in_axis, level, gpr = False, gpr, None
#     887     else:
# --> 888         raise KeyError(gpr)
#     889 elif isinstance(gpr, Grouper) and gpr.key is not None:
#     890     # Add key to exclusions
#     891     exclusions.add(gpr.key)
#
# KeyError: 'Cluster'
